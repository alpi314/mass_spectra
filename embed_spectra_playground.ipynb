# %%
import pickle
documents = pickle.load(open("./dataset/TBDMS_preprocessed/documents.pickle", "rb"))

# %%
import gensim
model = gensim.models.Word2Vec.load("./models/TBDMS.model")

# %%
from spec2vec import Spec2Vec
model = Spec2Vec(model)

# %%
model._calculate_embedding(documents[0])
# Out:
# array([ 1.88787160e+01,  2.52476828e+00, -1.76826015e+00,  3.20885576e+00,
#         3.41020774e+00,  1.19347293e+01,  1.78303340e+00,  7.27865927e+00,
#         4.67272764e+00, -1.91149274e+00, -3.61626253e+00, -6.02975328e+00,
#        -5.08480030e+00,  5.72484538e-01, -3.41372290e+00, -4.97356557e+00,
#         1.15665497e+01,  2.98762079e-01,  1.15672643e+00,  1.76348752e+00,
#        -4.03446495e+00, -1.17048779e+01,  3.46278800e+00, -1.89447638e+00,
#         1.83273617e+00,  2.40802757e-01, -1.43536687e-01, -1.95058258e+00,
#        -3.48905700e+00,  3.15872456e+00, -7.75357619e-01, -8.69433865e+00,
#         4.99090712e+00, -1.30767584e-01,  1.95771143e-01,  6.40579475e+00,
#        -3.77355851e-01,  7.09832481e+00, -9.41875663e-01,  6.41263466e+00,
#         5.74757160e+00, -1.28031555e+00, -1.14322032e+00, -1.37121201e+00,
#         1.06195593e+01,  6.73759125e-01, -7.72721534e+00,  3.35769443e+00,
# ...
